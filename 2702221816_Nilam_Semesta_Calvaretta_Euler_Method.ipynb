# %% [markdown]
# <a href="https://colab.research.google.com/github/NCalvaretta/Lab-Algorithm-and-Programming/blob/main/2702221816_Nilam_Semesta_Calvaretta_Euler_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
# %matplotlib inline

# Define parameters
f = lambda t, s: np.exp(-t) # ODE
h = 0.1 # Step size
t = np.arange(0, 1+h, h) # Numerical grid
s0 = -1 # Initial condition

# Explicit Euler Method
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) -1):
    s[i+1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (12, 8))
plt.plot(t, s, 'bo--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution for Simpple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc = 'lower right')
plt.show()
# Out:
# <ipython-input-7-4d182fc9ea61>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %%
h = 0.01 # Step size
t = np.arange(0, 1+h, h) # Numerical grid
s0 = -1 # Initial Condition

# Explicit Euler Method
s = np.zeros(len(t))
s[0] = s0

for i in range(0, len(t) - 1):
    s[i+1] = s[i] + h*f(t[i], s[i])

plt.figure(figsize = (12, 8))
plt.plot(t, s, 'b--', label='Approximate')
plt.plot(t, -np.exp(-t), 'g', label='Exact')
plt.title('Approximate and Exact Solution for simple ODE')
plt.xlabel('t')
plt.ylabel('f(t)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Quiz 1
#
# y' + 4y = x^2
# y(0) = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
# %matplotlib inline

# Define the differential equation y' + 4y = x^2
f = lambda x, y: x**2 - 4*y

# Define parameters
h = 0.1 # Step size
x = np.arange(0, 1+h, h) # Numerical grid
y0 = 1 # Initial condition

# Explicit Euler Method
y = np.zeros(len(x))
y[0] = y0

for i in range(0, len(x) - 1):
    y[i+1] = y[i] + h*f(x[i], y[i])

# Exact solution for the given differential equation
exact_solution = lambda x: (1/4) * x**2 - (1/8) * x**4 + (33/32) * np.exp(-4*x) - 1/32

# Plotting the results
plt.figure(figsize = (12, 8))
plt.plot(x, y, 'bo--', label='Approximate')
plt.plot(x, exact_solution(x), 'g', label='Exact')
plt.title('Approximate and Exact Solution for y\' + 4y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend(loc = 'lower right')
plt.show()
# Out:
# <ipython-input-8-baf14e1f60c0>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')

# %% [markdown]
# Quiz 1 Part 2
#
# x = 0
# y(0) = 1
# y(0,1)=?

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
# %matplotlib inline

# Define the differential equation y' + 4y = x^2
f = lambda x, y: x**2 - 4*y

# Define parameters
h = 0.1 # Step size
x = np.arange(0, 1+h, h) # Numerical grid
y0 = 1 # Initial condition

# Explicit Euler Method
y = np.zeros(len(x))
y[0] = y0

for i in range(0, len(x) - 1):
    y[i+1] = y[i] + h*f(x[i], y[i])

# Plotting the results
plt.figure(figsize = (12, 8))
plt.plot(t, y, 'bo--', label='Approximate')
plt.title('Approximate Solution for y\' + 4y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend(loc = 'lower right')
plt.show()

# Print the result of y at x = 0.1
print(f'y(0.1) = {y[1]}')
# Out:
# <ipython-input-13-c314ab27e784>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# y(0.1) = 0.6

# %% [markdown]
# Quiz 2
#
# y' = sin y
# y(0) = 1
# h = 0,1
# x = from 0 to 5

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
# %matplotlib inline

# Define the differential equation y' = sin(y)
f = lambda t, y: np.sin(y)

# Define parameters
h = 0.1 # Step size
t = np.arange(0, 0.5+h, h) # Numerical grid
y0 = 1 # Initial condition

# Explicit Euler Method
y = np.zeros(len(t))
y[0] = y0

for i in range(0, len(t) - 1):
    y[i+1] = y[i] + h*f(t[i], y[i])

# Plotting the results
plt.figure(figsize = (12, 8))
plt.plot(t, y, 'bo--', label='Approximate')
plt.title('Approximate Solution for y\' = sin(y)')
plt.xlabel('t')
plt.ylabel('y')
plt.grid()
plt.legend(loc = 'lower right')
plt.show()

# Print the result of y at t = 0.1
print(f'y(0.1) = {y[1]}')
# Out:
# <ipython-input-17-9cf47362d0a9>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-poster')
# y(0.1) = 1.0841470984807897
